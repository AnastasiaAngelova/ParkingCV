# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !nvidia-smi
# Out:
# Thu Apr 11 16:34:39 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 546.17                 Driver Version: 546.17       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 2060      WDDM  | 00000000:01:00.0  On |                  N/A |
# |  0%   50C    P8              18W / 170W |   1098MiB /  6144MiB |     24%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# d:\TestTasks\SergThesisParking\ParkingCV

# %%
# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196  Python-3.11.5 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Setup complete  (12 CPUs, 15.9 GB RAM, 1483.9/1863.0 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
model = YOLO(f'yolov8n.pt')

# %%
model.train(data=f"{HOME}/data/yolo/data.yaml", imgsz=256, plots=True, task="detect", epochs=25)
# Out:
# New https://pypi.org/project/ultralytics/8.1.46 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196  Python-3.11.5 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...

# %%
best_model = YOLO(f"{HOME}/runs/detect/train16/weights/best.pt")

# %%
best_model.val(data=f"{HOME}/data/yolo/data.yaml")
# Out:
# Ultralytics YOLOv8.0.196  Python-3.11.5 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning D:\TestTasks\SergThesisParking\ParkingCV\data\yolo\valid\labels.cache... 2483 images, 59 backgrounds, 0 c
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 156/156 [01:
#                    all       2483     143316      0.959      0.933      0.975       0.71
#            space-empty       2483      73629      0.948      0.938       0.97      0.699
#         space-occupied       2483      69687      0.971      0.928      0.979       0.72
# Speed: 0.2ms preprocess, 2.5ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to runs\detect\val2
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# box: ultralytics.utils.metrics.Metric object
# ...

# %%
best_model.predict(task="detect", source="./data\yolo\\test\images\\2012-09-11_15_53_00_jpg.rf.8d1b56dcd21d8440995498ef8807577f.jpg", conf=0.25, save=True)
# Out:
# image 1/1 d:\TestTasks\SergThesisParking\ParkingCV\data\yolo\test\images\2012-09-11_15_53_00_jpg.rf.8d1b56dcd21d8440995498ef8807577f.jpg: 160x256 26 space-emptys, 71 space-occupieds, 54.3ms
# Speed: 5.0ms preprocess, 54.3ms inference, 28.0ms postprocess per image at shape (1, 3, 160, 256)
# Results saved to runs\detect\predict6
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'space-empty', 1: 'space-occupied'}
#  orig_img: array([[[116, 146, 163],
#          [118, 148, 165],
#          [122, 149, 170],
#          ...,
#          [ 44, 116, 128],
#          [ 48, 122, 134],
#          [ 52, 126, 138]],
#
#         [[117, 145, 162],
#          [119, 147, 164],
#          [121, 148, 169],
#          ...,
#          [ 48, 120, 130],
#          [ 52, 124, 136],
#          [ 53, 128, 137]],
#
#         [[118, 144, 161],
#          [120, 146, 163],
#          [122, 146, 168],
# ...
